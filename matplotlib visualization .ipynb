# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoint=np.array([0,6])
ypoint=np.array([0,250])
plt.plot(xpoint,ypoint)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoint=np.array([1,9])
ypoint=np.array([5,10])
plt.plot(xpoint,ypoint)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoint=np.array([1,2,3,0,5,6])
ypoint=np.array([3,4,5,4,8,10])
plt.plot(xpoint,ypoint)
plt.show()

# %%
ypoints=np.array([2,8,9,3,1,0])
plt.plot(ypoint,marker="o")
plt.show()

# %%
ypoints=np.array([2,8,9,3,1,0])
plt.plot(ypoint,marker="*")
plt.show()

# %%
ypoints=np.array([2,8,9,3,1,0])
plt.plot(ypoint,"o:g")
plt.show()

# %%
ypoints=np.array([2,8,9,3,1,0])
plt.plot(ypoint,"o:b")
plt.show()

# %%
ypoints=np.array([2,8,9,3,1,0])
plt.plot(ypoint,linestyle="dotted")
plt.show()

# %%
ypoints=np.array([2,9,4,1,12])
plt.plot(ypoint,linewidth="20.2")
plt.show()

# %%
y1=([2,33,46,89])
y2=([23,11,5,89])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
y=([1,2,3,4,5,6,7,8])
x=([1,2,3,4,5,6,7,8])
plt.plot(x,y)
plt.xlabel("average")
plt.ylabel("maxium")
plt.show()

# %%
y=([1,2,3,4,5,6,7,8])
x=([1,2,3,4,5,6,7,8])
plt.plot(x,y)
plt.title("project")
plt.xlabel("average")
plt.ylabel("maxium")
plt.show()

# %%
x=np.array([0,1,2,3])
y=np.array([3,8,9,1])
plt.subplot(1,2,1)
plt.plot(x,y)
x=([0,1,2,3])
y=([2,56,21,1])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
x=np.array([0,1,2,3])
y=np.array([2,56,21,1])
plt.scatter(x,y)
plt.show()

# %%
x=np.array(["a","b","c","d"])
y-np.array([3,8,1,6])
plt.bar(x,y)
plt.show()

# %%
x=np.array(["a","b","c","d"])
y-np.array([3,8,1,6])
plt.bar(x,y,color="r")
plt.show()

# %%
x=np.array(["a","b","c","d"])
y-np.array([3,8,1,6])
plt.bar(x,y,color="g")
plt.show()

# %%
x=np.array(["a","b","c","d"])
y-np.array([3,8,1,6])
plt.bar(x,y,color="y")
plt.show()

# %%
x=np.array(["a","b","c","d"])
y-np.array([3,8,1,6])
plt.bar(x,y,width=0.1)
plt.show()

# %%
x=np.random.normal(170,10,230)
plt.hist(x)
plt.show()

# %%
y=np.array([35,66,12,90])
plt.pie(y)
plt.show()

# %%
y=np.array([35,66,12,90])
mylabels=["apples","banana","cherry","peach"]
plt.pie(y,labels=mylabels)
plt.show()

# %%
y=np.array([22,31,45,98,10])
mylabels=["orange","mango","rasberry","blueberry"]
plt.pie(y,labels=mylabels)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 y=np.array([22,31,45,98,10])
#       2 mylabels=["orange","mango","rasberry","blueberry"]
# ----> 3 plt.pie(y,labels=mylabels)
#       4 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...
